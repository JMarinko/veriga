# %%
import numpy as np
from scipy import optimize as opt
from scipy.interpolate import UnivariateSpline as uni
import matplotlib.pyplot as plt

# %% [markdown]
# ### Podatki DIN 8190 (8191)

# %%
# Oblika [ime, p, f, g1, g2, 2c, u, y, prvi korekcijski faktor za radije(moj popravek)]
podatki = [['06', 9.525, 3.76, 10.9, 6.7],
           ['08', 12.7, 5.085, 14.45, 8.7],
           ['12', 19.05, 7.44, 21, 10.7],
           ['16', 25.4, 10.04, 27.7, 14],
           ['24', 38.1, 14.95, 41, 21],
           ['32', 50.8, 19.93, 55, 28]]
omega = 200  # s^-1

# %% [markdown]
# ### Člen

# %%
class Clen_lep():
    
    def __init__(self, podatki_i):
        ime, self.p, self.f, self.g1, self.g2 = podatki_i
        self.e = self.g2 / 7

        # Podatki
        self.alpha_k = 30
        self.alpha_r = np.deg2rad(self.alpha_k)
    
        # Resevanje
        zac_priblizki = np.zeros(32)
        zac_priblizki = [0, -1, 1.5, 3.7, 0, 1, 3.7, 4.7, 4.7, 5, 0, 1, 2.5, 1.5,\
                        self.p / 2, self.g1-self.g2, 0, self.g1-self.g2, - self.f * np.cos(self.alpha_r),\
                         - self.f * np.sin(self.alpha_r), 0, -self.g2, 0, self.g2, 0, self.g2, self.p / 3, -self.g2 / 4,\
                        4, 1, 1, 2]
        resitev = list(opt.fsolve(self.enacbe, zac_priblizki))
        print(resitev)
        
        t1A, t1B, t2B, t2C, t3C, t3D, t4D, t4E, t5E, t5F, t6F, t6G, t7G, t7H, x01, y01, x02, y02, \
        x03, y03, x04, y04, x05, y05, x06, y06, x07, y07, r2, r4, r5, r7 = resitev
        
        st = 50
        self.x = []
        self.y = []
        
        # AB
        t1_ = np.linspace(t1A, t1B, st)
        self.x.append(self.x1(t1_, x01, x02))
        self.y.append(self.y1(t1_, y01, y02))
        
        # BC
        t2_ = np.linspace(t2B, t2C, st)
        self.x.append(self.x2(t2_, x02, r2))
        self.y.append(self.y2(t2_, y02, r2))
        
        # CD
        t3_ = np.linspace(t3C, t3D, st)
        self.x.append(self.x3(t3_, x03, x04))
        self.y.append(self.y3(t3_, y03, y04))
        
        # DE
        t4_ = np.linspace(t4D, t4E, st)
        self.x.append(self.x4(t4_, x04, r4))
        self.y.append(self.y4(t4_, y04, r4))
        
        # EF
        t5_ = np.linspace(t5E, t5F, st)
        self.x.append(self.x5(t5_, x05, r5))
        self.y.append(self.y5(t5_, y05, r5))
        
        # FG
        t6_ = np.linspace(t6F, t6G, st)
        self.x.append(self.x6(t6_, x06, x07))
        self.y.append(self.y6(t6_, y06, y07))
        
        # GH
        t7_ = np.linspace(t7G, t7H, st)
        self.x.append(self.x7(t7_, x07, r7))
        self.y.append(self.y7(t7_, y07, r7))
        
        self.x = np.array(self.x)
        self.y = np.array(self.y)
        
        '''
        self.x = self.x0[::]
        self.y = self.y0[::]
        for i in range(len(self.x)):
            self.x.append(-self.x0[-(i+1)][::-1])
            self.y.append(np.array(self.y0[-(i+1)][::-1]))
        self.x = np.array(self.x)
        self.y = np.array(self.y)
        self.tocka0 = [0.0 - self.a / 2 - self.sm, 0.0, 0.0 + self.a / 2 + self.sm, 0.0]
        '''

    # Enacbe
    # t1A t2B
    def x1(self, t1, x01, x02):
        return x01 + (x02 - x01) * t1
    def y1(self, t1, y01, y02):
        return y01 + (y02 - y01) * t1
    
    # t2A t2B
    def x2(self, t2, x02, r2):
        return x02 + r2 * np.cos(t2) 
    def y2(self, t2, y02, r2):
        return y02 + r2 * np.sin(t2)
    
    # t3A t3B
    def x3(self, t3, x03, x04):
        return x03 + (x04 - x03) * t3
    def y3(self, t3, y03, y04):
        return y03 + (y04 - y03) * t3
 
    # t4A t4B
    def x4(self, t4, x04, r4):
        return x04 + r4 * np.cos(t4) 
    def y4(self, t4, y04, r4):
        return y04 + r4 * np.sin(t4)
    
    # t5A t5B
    def x5(self, t5, x05, r5):
        return x05 + r5 * np.cos(t5) 
    def y5(self, t5, y05, r5):
        return y05 + r5 * np.sin(t5)
    
    # t6A t6B
    def x6(self, t6, x06, x07):
        return x06 + (x07 - x06) * t6
    def y6(self, t6, y06, y07):
        return y06 + (y07 - y06) * t6
   
    # t7A t7B
    def x7(self, t7, x07, r7):
        return x07 + r7 * np.cos(t7) 
    def y7(self, t7, y07, r7):
        return y07 + r7 * np.sin(t7)
    
    # Sistem enacb
    def enacbe(self, priblizki):
        '''Potrebujem pri določanju geometrije zobnika'''
        t1A, t1B, t2B, t2C, t3C, t3D, t4D, t4E, t5E, t5F, t6F, t6G, t7G, t7H, \
        x01, y01, x02, y02, x03, y03, x04, y04, x05, y05, x06, y06, x07, y07, r2, r4, r5, r7 = priblizki
        # Zveznost x: 6
        e1 = self.x2(t2B, x02, r2) - self.x1(t1B, x01, x02)
        e2 = self.x3(t3C, x03, x04) - self.x2(t2C, x02, r2)
        e3 = self.x4(t4D, x04, r4) - self.x3(t3D, x03, x04)
        e4 = self.x5(t5E, x05, r4) - self.x4(t4E, x04, r4)
        e5 = self.x6(t6F, x06, x07) - self.x5(t5F, x05, r4)
        e6 = self.x7(t7G, x07, r7) - self.x6(t6G, x06, x07)
        # Zveznost y: 6
        e7 = self.y2(t2B, y02, r2) - self.y1(t1B, y01, y02)
        e8 = self.y3(t3C, y03, y04) - self.y2(t2C, y02, r2)
        e9 = self.y4(t4D, y04, r4) - self.y3(t3D, y03, y04)
        e10 = self.y5(t5E, y05, r4) - self.y4(t4E, y04, r4)
        e11 = self.y6(t6F, y06, y07) - self.y5(t5F, y05, r4)
        e12 = self.y7(t7G, y07, r7) - self.y6(t6G, y06, y07)
        # Odvodi: 8
        e13 = y02 - y01
        e14 = np.sin(t2B)
        e15 = np.tan(t2C) + np.pi / 3
        e16 = np.tan(t4D) + np.pi / 3
        e17 = t4E - t5E
        e18 = np.tan(t5E) - np.pi / 3
        e19 = np.tan(t7G) - np.pi / 3
        e20 = np.sin(t7H)
        
        '''
        # Odvodi: 8
        e13 = (y02 - y01) / (x02 - x01)
        e14 = (np.sin(t2B) / np.cos(t2B)) - (y02 - y01) / (x02 - x01)
        e15 = ((y04 - y03) / (x04 - x03)) - (np.sin(t2C) / np.cos(t2C))
        e16 = (np.sin(t4D) / np.cos(t4D)) - (y04 - y03) / (x04 - x03)
        e17 = t4E - t5E
        e18 = (y07 - y06) / (x07 - x06) - (np.sin(t5F) / np.cos(t5E))
        e19 = (np.sin(t7G) / np.cos(t7G)) - ((y07 - y06) / (x07 - x06))
        e20 = np.sin(t7H) / np.cos(t7H)'''
        
        # Ostalo: 11
        e21 = 0.5 * self.p - self.x1(t1A, x01, x02)
        e22 = (self.g1 - self.g2) - self.y1(t1A, y01, y02)
        e23 = - self.f * np.cos(self.alpha_r) - self.x3(t3C, x03, x04)
        e24 = - self.f * np.sin(self.alpha_r) - self.y3(t3C, y03, y04)
        e25 = (y04 - y03) + np.pi / 3 * (x04 - x03)
        e26 = y04 - y06
        e27 = y05 + self.g2
        e28 = x05
        e29 = (y07 - y06) - np.pi / 3 * (x07 - x06)
        e30 = self.x7(t7H, x07, r7) - 0.5 * self.p
        e31 = self.y7(t7H, y07, r7) + self.e
        e32 = r5 - r4
        return (e1, e2, e3, e4, e5, e6, e7, e8, e9, e10, e11, e12, e13, e14, e15, e16, e17, e18, e19, e20,
                e21, e22, e23, e24, e25, e26, e27, e28, e29, e30, e31, e32)
    
    def izris(self):
        "Izriše clen."
        plt.plot(self.x.flatten(), self.y.flatten())
        #plt.plot(self.tocka0[0:3:2], self.tocka0[1:4:2], 'o')
        plt.axis('equal')
        plt.grid()
        
    def rotacija(self, kot):  # kot v rad
        '''Naceloma je za clen ne potrebujem.'''
        for i, odsek_x, odsek_y in zip(range(len(self.x)), self.x, self.y):
            for j, x_z, y_z in zip(range(len(odsek_x)), odsek_x, odsek_y):
                x_n = x_z * np.cos(kot) - y_z * np.sin(kot)  # novi x
                y_n = x_z * np.sin(kot) + y_z * np.cos(kot)  # novi y
                self.x[i][j] = x_n
                self.y[i][j] = y_n
        # tocka 0
        x0nl = self.tocka0[0] * np.cos(kot) - self.tocka0[1] * np.sin(kot)
        y0nl = self.tocka0[0] * np.sin(kot) + self.tocka0[1] * np.cos(kot)
        x0nd = self.tocka0[2] * np.cos(kot) - self.tocka0[3] * np.sin(kot)
        y0nd = self.tocka0[2] * np.sin(kot) + self.tocka0[3] * np.cos(kot)
        self.tocka0 = [x0nl, y0nl, x0nd, y0nd]
                
    def translacija_x(self, pomik):
        '''Za pomik premakne clen po x osi.'''
        self.x += pomik
        self.tocka0[0] += pomik
        self.tocka0[2] += pomik
        
    def translacija_y(self, pomik):
        '''Za pomik premakne clen po y osi.'''
        self.y += pomik
        self.tocka0[1] += pomik
        self.tocka0[3] += pomik

# %%
#Preizkus razreda clen:
c = Clen_lep(podatki[0])
#c.rotacija(np.pi / 6)
#c.translacija_x(20)
c.izris()
# Out:
# [-142.5159667511282, 0.5211408736885682, -9.42429899727891, 2.3335460476679066, 0.2801919638099962, -19.7577972060549, 2.3327234920156497, 4.130598497819396, 4.1449631301918535, -30.559286829749965, 26.63100577301694, 2.750166843268393, 3.9459725861628976, -15.710676508564914, -3.246549826469872, -1.8218534352968743, -3.3027464711698866, -1.8641041069611828, -5.848994525419064, 0.8181876451309497, 3.356516759750748, -8.829914716987533, 0.011904189247284301, -6.680851194243391, -22.141887435983026, -8.840404894303209, -14.502067287682788, -0.9047634799650646, -0.03249120921101411, 276.80847032924004, 276.8066799358268, -19.27359578436934]

# %% [markdown]
# ### Verižnik

# %%
class Veriznik():
    
    def __init__(self, podatki_i, z):

        ime, p, f, g1, g2, c, u, y, fc = podatki_i
        z = z
        
        alpha_k = 30
        alpha_r = np.deg2rad(alpha_k)
        razdelni_premer = (z * p) / np.pi
        self.znacilna_hitrost = razdelni_premer / 2 * omega
        osnovni_premer = razdelni_premer * np.cos(alpha_r)
        addendum = 1 * p / np.pi
        dedendum = 1.25 * p / np.pi
        self.zunanji_premer = razdelni_premer + 2 * addendum
        self.krozni_korak = p / (razdelni_premer / 2)
        krozna_debelina_zoba = p / 2
        krozni_kot_zoba = krozna_debelina_zoba / (razdelni_premer / 2)

        u = 0
        r_trenutni = 0
        x_evo0 = [self.f_x_evolventa(osnovni_premer / 2, u)]
        y_evo0 = [self.f_y_evolventa(osnovni_premer / 2, u)]
        while r_trenutni < self.zunanji_premer / 2:
            napaka = 0.000002  # korak po katerem se pomika cez točke  0.000002
            u += napaka
            x_trenutni = self.f_x_evolventa(osnovni_premer / 2, u)
            y_trenutni = self.f_y_evolventa(osnovni_premer / 2, u)
            x_evo0.append(x_trenutni)
            y_evo0.append(y_trenutni)
            r_trenutni = np.sqrt(x_trenutni ** 2 + y_trenutni ** 2)
            if abs(r_trenutni - razdelni_premer / 2) <= ((razdelni_premer - osnovni_premer) / 2) / len(x_evo0):
                xy_razdelni = (x_trenutni, y_trenutni)

        zeljeno_stevilo_tock = 300  # število točk, ki jih uporabim na posameznem odseku. Če to želim zvečati,
                                    # moram zmanjšati korak! Drugače analiza: "Error: array without sequence."  500
        korak_po_tockah = int(len(x_evo0) / zeljeno_stevilo_tock) + 1
        x_evo1 = x_evo0[::korak_po_tockah]
        y_evo1 = y_evo0[::korak_po_tockah]

        phi = np.arctan(xy_razdelni[1] / xy_razdelni[0])    
        x_evo1a, y_evo1a = self.obrni(x_evo1, y_evo1, -phi)

        y_evo1_z = -y_evo1a  # zrcalno
        x_evo2, y_evo2 = self.obrni(x_evo1a, y_evo1a, - krozni_kot_zoba / 2)
        x_evo2_z, y_evo2_z = self.obrni(x_evo1a, y_evo1_z, krozni_kot_zoba / 2)
        x_evo2_v = np.zeros(zeljeno_stevilo_tock) + x_evo2[-1]  # vmes
        y_evo2_v = np.linspace(y_evo2_z[-1], y_evo2[-1], zeljeno_stevilo_tock)

        xz0, yz0 = self.obrni(x_evo2_z, y_evo2_z, np.pi / 2 + self.krozni_korak)
        xz1, yz1 = self.obrni(x_evo2_v, y_evo2_v, np.pi / 2 + self.krozni_korak)
        xz2, yz2 = self.obrni(x_evo2[::-1], y_evo2[::-1], np.pi / 2 + self.krozni_korak)

        xz3, yz3 = self.obrni(x_evo2_z, y_evo2_z, np.pi / 2)
        xz4, yz4 = self.obrni(x_evo2_v, y_evo2_v, np.pi / 2)
        xz5, yz5 = self.obrni(x_evo2[::-1], y_evo2[::-1], np.pi / 2)

        xz6, yz6 = self.obrni(x_evo2_z, y_evo2_z, np.pi / 2 - self.krozni_korak)
        xz7, yz7 = self.obrni(x_evo2_v, y_evo2_v, np.pi / 2 - self.krozni_korak)
        xz8, yz8 = self.obrni(x_evo2[::-1], y_evo2[::-1], np.pi / 2 - self.krozni_korak)

        self.x = np.array([xz0, xz1, xz2, xz3, xz4, xz5, xz6, xz7, xz8])
        self.y = np.array([yz0, yz1, yz2, yz3, yz4, yz5, yz6, yz7, yz8])
    
    def obrni(self, seznam_x, seznam_y, kot):  # kot v rad
        '''Ta funkcija nam služi le pri obračanju delov, ko sestavljamo zobnik. V nadaljevanju za vrtenje zobnika
        uporabljamo metodo rotacija.'''
        nov_seznam_x = []
        nov_seznam_y = []
        for x_z, y_z in zip(seznam_x, seznam_y):  # x_zacetni, y_zacetni
            x_n = x_z * np.cos(kot) - y_z * np.sin(kot)  # novi x
            y_n = x_z * np.sin(kot) + y_z * np.cos(kot)  # novi y
            nov_seznam_x.append(x_n)
            nov_seznam_y.append(y_n)
        return (np.array(nov_seznam_x), np.array(nov_seznam_y))

    def f_x_evolventa(self, a, u):
        return a * (np.cos(u) + u * np.sin(u))

    def f_y_evolventa(self, a, u):
        return a * (np.sin(u) - u * np.cos(u))
    
    def rotacija(self, kot):  # kot v rad
        '''Zavrti zobnik za kot "kot".'''
        for i, odsek_x, odsek_y in zip(range(len(self.x)), self.x, self.y):
            for j, x_z, y_z in zip(range(len(odsek_x)), odsek_x, odsek_y):
                x_n = x_z * np.cos(kot) - y_z * np.sin(kot)  # novi x
                y_n = x_z * np.sin(kot) + y_z * np.cos(kot)  # novi y
                self.x[i][j] = x_n
                self.y[i][j] = y_n
    
    def izris(self):
        "Izriše veriznik."
        plt.plot(self.x.flatten(), self.y.flatten(), 'r')
        plt.axis('equal')
        plt.grid()

# %%
# Preizkus razreda verižnik:
v = Veriznik(podatki[0], 25)
#v.rotacija(-np.pi/10)
v.izris()

# %% [markdown]
# ### Analiza

# %%
def premicno_povprecje(array, st_tock):
    na = []
    st_pred = int((st_tock-1)/2)  # število točk pred in za sredinsko
    na.append(array[0])
    for i in range(1, st_pred):
        na.append(np.average(array[0:i]))
    for i in range(st_pred, int(len(array)-st_pred)):
        na.append(np.average(array[i-int((st_tock-1)/2):i+st_pred]))
    for i in range(1, st_pred + 1)[::-1]:
        na.append(array[-i])
    return na

# %%
class Analiza():
    
    '''Vzame podatke za clen in veriznik (podatki_i in z) in ju pribliza s funkcijo priblizaj.
    Nato ju zavrti in vrne tocke kontakta.'''
    
    def __init__(self, podatki_i, z, kot_analize, prikazi):
        ime = podatki_i[0] 
        print("LEP PRIKAZ\nVrsta: ", ime)
        print("Število zob: ", z)
        self.c = Clen_lep(podatki_i)
        self.v = Veriznik(podatki_i, z)
        self.kot_analize = kot_analize
        self.lastni_cas = self.kot_analize / omega
        self.premik_clena = self.v.znacilna_hitrost * self.lastni_cas
        
        # Skupni seznami
        self.x_c = []
        self.y_c = []
        self.x_v = []
        self.y_v = []
        
        self.priblizaj()
        self.izris()
        self.analiza = True
        stevec = 1
        while self.analiza == True:
            if stevec % 10 == 0 and prikazi:  # izriše le vsako 10 - to
                self.izris()
            self.nov_korak_obravnave()
            stevec += 1
            
        # Ogled in obdelava rezultatov
        # self.izris_ubirnice()
        self.glajenje_ubirnice()
        self.izris_ubirnice()
        self.relativne_hitrosti()
            
    def priblizaj(self):
        
        '''Pribliza clen in verižnik v prvo situacijo za analizo'''
        # Premik člena
        self.c.translacija_y(self.v.zunanji_premer)

        # Iskanje začetne zračnosti - gledam le na spoj med levim delom člena in levim zobom
        min_razdalja = None
        for i, (x_c, y_c) in enumerate(zip(self.c.x[3], self.c.y[3])):
            for j, (x_v, y_v) in enumerate(zip(self.v.x[2], self.v.y[2])):
                try:  # Zadnjega clena ne more, ker je index out of range [i+1]
                    if abs(x_v - x_c) < abs(x_c - self.c.x[3][i+1])/2 and abs(x_v - x_c) < abs(x_v - self.v.x[[2],[j+1]])/2:
                        razdalja = y_c - y_v
                        if razdalja < 0:
                            raise Exception("Se že sekata!")
                        elif min_razdalja == None or razdalja < min_razdalja[-1]:
                            min_razdalja = [i, j, x_c, y_c, x_v, y_v, razdalja]
                except:  # Za try mora vedno pridet še except.
                    break
        self.c.translacija_y(-min_razdalja[-1])
        
        # Pripenjanje v sezname
        self.x_c.append(min_razdalja[2])
        self.y_c.append(min_razdalja[5] - min_razdalja[-1])
        self.x_v.append(min_razdalja[4])
        self.y_v.append(min_razdalja[5])
        
        if min_razdalja[0] == -1:
            self.analiza = False
            print("Zadnja točka na odseku.")
        
    def nov_korak_obravnave(self):
        '''Obrne zobnik, približa člen in vpiše točke kontakta'''
        self.v.rotacija(-self.kot_analize)
        self.c.translacija_x(1.2 * self.premik_clena)
        
        min_razdalja = None
        for i, (x_c, y_c) in enumerate(zip(self.c.x[3], self.c.y[3])):
            for j, (x_v, y_v) in enumerate(zip(self.v.x[2], self.v.y[2])):
                try:  # Zadnjega clena ne more, ker je index out of range [i+1]
                    if abs(y_v - y_c) < abs(y_c - self.c.y[3][i+1])/2:  # and abs(y_v - y_c) < abs(y_v - self.v.y[[2],[j+1]])/2:
                        razdalja = x_v - x_c
                        if min_razdalja == None or abs(razdalja) < abs(min_razdalja[-1]):
                            min_razdalja = [i, j, x_c, y_c, x_v, y_v, razdalja]
                except:  # Za try mora vedno pridet še except.
                    break

        if abs(min_razdalja[-1]) < 0.25 * self.premik_clena:
            self.c.translacija_x(min_razdalja[-1])

            # Pripenjanje v sezname
            self.x_c.append(min_razdalja[2])
            self.y_c.append(min_razdalja[3] - min_razdalja[-1])
            self.x_v.append(min_razdalja[4])
            self.y_v.append(min_razdalja[5])
            
        else:
            self.analiza = False  # Izklopi while zanko
                               
    def izris(self):
        '''Izriše člen in verižnik.'''
        self.c.izris()
        self.v.izris()
        plt.show()
    
    def izris_ubirnice(self):
        # Predpostavka kontaktne točke verižnika in člena so enake - zanemarimo napako numerične metode.
        plt.plot(self.x_v, self.y_v, 'g.')
        plt.title("Ubirnica")
        plt.xlabel("mm")
        plt.ylabel("mm")
        plt.show()
        
    def glajenje_ubirnice(self):
        '''Pogladim y vrednosti točk s premičnim povprečjem.'''
        # print("Glajenje ubirnice...")
        self.y_g = premicno_povprecje(self.y_v, 7)
        self.y_v = self.y_g
    
    def relativne_hitrosti(self):
        self.rel_hitrosti = []
        self.koti_kontakta = []
        self.koti_veriznika = []
        self.normalne_hitrosti = []
        kot_veriznika = np.pi / 2
        for x, y in zip(self.x_v, self.y_v):
            r = np.sqrt(x ** 2 + y ** 2)
            v_obodna = omega * r
            theta = np.arctan(y / x)
            if theta < 0:
                theta += np.pi
            phi1 = np.pi - self.c.alpha_r -theta
            phi2 = np.deg2rad(60)
            v_rel = v_obodna * (np.cos(phi1) - np.sin(phi1) / np.tan(phi2))
            v_n = v_obodna * np.sin(phi1)
            self.rel_hitrosti.append(v_rel / 1000)  # pretvorim iz mm/s v m/s
            self.normalne_hitrosti.append(v_n / 1000)  # pretvorim iz mm/s v m/s
            self.koti_kontakta.append(np.rad2deg(theta))
            self.koti_veriznika.append(np.rad2deg(kot_veriznika))
            kot_veriznika -= self.kot_analize
            
        # Izris
        plt.plot(self.koti_kontakta, self.rel_hitrosti, '.')
        plt.title('Drsna hitrost v odvisnosti od kota kontakta')
        plt.xlabel('°')
        plt.ylabel("$\\frac{m}{s}$")
        plt.show()
        
        plt.plot(self.koti_kontakta, self.normalne_hitrosti, '.')
        plt.title('Normalna hitrost v odvisnosti od kota kontakta')
        plt.xlabel('°')
        plt.ylabel("$\\frac{m}{s}$")
        plt.show()
        
        '''
        plt.plot(self.koti_veriznika, self.rel_hitrosti, '.')
        plt.title('Relativne hitrosti v odvisnosti od kota veriznika')
        plt.xlabel('°')
        plt.ylabel("$\\frac{m}{s}$")
        plt.show()
        '''

# %%
Analiza(podatki[0], 30, np.pi / 300, 1);  # Za prikaz
for i in range(6):    
    for z in range(20, 36, 5): #25,36,5
        Analiza(podatki[i], z, np.pi/300, 0);  # Dobro: st tock obeh 500, pi/500, korak = 0.000002
# Če želim pohitrit, spremeni št točk verižnika in
# predvsem korak zanko prej -> "napaka".
# Out:
# LEP PRIKAZ
# Vrsta:  06
# Število zob:  30
# LEP PRIKAZ
# Vrsta:  06
# Število zob:  20
# LEP PRIKAZ
# Vrsta:  06
# Število zob:  25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-c08ad0f8199a> in <module>
#       2 for i in range(6):
#       3     for z in range(20, 36, 5): #25,36,5
# ----> 4         Analiza(podatki[i], z, np.pi/300, 0);  # Dobro: st tock obeh 500, pi/500, korak = 0.000002
#       5 # Če želim pohitrit, spremeni št točk verižnika in
#       6 # predvsem korak zanko prej -> "napaka".
#
# <ipython-input-45-b6daa8638c1f> in __init__(self, podatki_i, z, kot_analize, prikazi)
#      33         # self.izris_ubirnice()
#      34         self.glajenje_ubirnice()
# ---> 35         self.izris_ubirnice()
#      36         self.relativne_hitrosti()
#      37
#
# <ipython-input-45-b6daa8638c1f> in izris_ubirnice(self)
#     107         plt.xlabel("mm")
#     108         plt.ylabel("mm")
# --> 109         plt.show()
#     110
#     111     def glajenje_ubirnice(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# C:\Moji programi\Anaconda3.7\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# C:\Moji programi\Anaconda3.7\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\Moji programi\Anaconda3.7\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# C:\Moji programi\Anaconda3.7\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# C:\Moji programi\Anaconda3.7\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\Moji programi\Anaconda3.7\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Moji programi\Anaconda3.7\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2277         for ax in self.axes:
#    2278             if ax.get_visible():
# -> 2279                 bb.append(ax.get_tightbbox(renderer, bbox_extra_artists))
#    2280
#    2281         if len(bb) == 0:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4205
#    4206         if self.title.get_visible():
# -> 4207             bb.append(self.title.get_window_extent(renderer))
#    4208         if self._left_title.get_visible():
#    4209             bb.append(self._left_title.get_window_extent(renderer))
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     929         bbox, info, descent = self._get_layout(self._renderer)
#     930         x, y = self.get_unitless_position()
# --> 931         x, y = self.get_transform().transform_point((x, y))
#     932         bbox = bbox.translated(x, y)
#     933         if dpi is not None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\transforms.py in transform_point(self, point)
#    1509         if len(point) != self.input_dims:
#    1510             raise ValueError("The length of 'point' must be 'self.input_dims'")
# -> 1511         return self.transform(np.asarray([point]))[0]
#    1512
#    1513     def transform_path(self, path):
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\transforms.py in transform(self, values)
#    1422
#    1423         # Transform the values
# -> 1424         res = self.transform_affine(self.transform_non_affine(values))
#    1425
#    1426         # Convert the result back to the shape of the input values.
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2432
#    2433     def transform_affine(self, points):
# -> 2434         return self.get_affine().transform(points)
#    2435     transform_affine.__doc__ = Transform.transform_affine.__doc__
#    2436
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\transforms.py in get_affine(self)
#    2460         else:
#    2461             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2462                                 self._a.get_affine().get_matrix()))
#    2463     get_affine.__doc__ = Transform.get_affine.__doc__
#    2464
#
# KeyboardInterrupt:

# %% [markdown]
# # Razširjeno dva člena

# %%
class Analiza2():
    
    '''Vzame podatke za clen in veriznik (podatki_i in z) in ju pribliza s funkcijo priblizaj.
    Nato ju zavrti in vrne tocke kontakta.'''
    
    def __init__(self, podatki_i, z, kot_analize, prikazi):
        ime = podatki_i[0] 
        print("Vrsta: ", ime)
        print("Število zob: ", z)
        self.c = Clen_lep(podatki_i)
        self.c2 = Clen_lep(podatki_i)
        self.v = Veriznik(podatki_i, z)
        self.v2 = Veriznik(podatki_i, z)
        self.kot_analize = kot_analize
        self.lastni_cas = self.kot_analize / omega
        self.premik_clena = self.v.znacilna_hitrost * self.lastni_cas
        
        # Skupni seznami
        self.x_c = []
        self.y_c = []
        self.x_v = []
        self.y_v = []
        
        self.priblizaj()
        self.izris()
        self.analiza = True
        stevec = 1
        while self.analiza == True:
            if stevec % 10 == 0 and prikazi:  # izriše le vsako 10 - to
                self.izris()
            self.nov_korak_obravnave()
            stevec += 1
            
        for i in range(5):
            self.nov_korak_obravnave()
        self.izris()
            
        # Ogled in obdelava rezultatov
        # self.izris_ubirnice()
        self.glajenje_ubirnice()
        self.izris_ubirnice()
        self.relativne_hitrosti()
            
    def priblizaj(self):
        
        '''Pribliza clen in verižnik v prvo situacijo za analizo'''
        # Premik člena
        self.c.translacija_y(self.v.zunanji_premer)

        # Iskanje začetne zračnosti - gledam le na spoj med levim delom člena in levim zobom
        min_razdalja = None
        for i, (x_c, y_c) in enumerate(zip(self.c.x[3], self.c.y[3])):
            for j, (x_v, y_v) in enumerate(zip(self.v.x[2], self.v.y[2])):
                try:  # Zadnjega clena ne more, ker je index out of range [i+1]
                    if abs(x_v - x_c) < abs(x_c - self.c.x[3][i+1])/2 and abs(x_v - x_c) < abs(x_v - self.v.x[[2],[j+1]])/2:
                        razdalja = y_c - y_v
                        if razdalja < 0:
                            raise Exception("Se že sekata!")
                        elif min_razdalja == None or razdalja < min_razdalja[-1]:
                            min_razdalja = [i, j, x_c, y_c, x_v, y_v, razdalja]
                except:  # Za try mora vedno pridet še except.
                    break
        self.c.translacija_y(-min_razdalja[-1])
        
        # Pripenjanje v sezname
        self.x_c.append(min_razdalja[2])
        self.y_c.append(min_razdalja[5] - min_razdalja[-1])
        self.x_v.append(min_razdalja[4])
        self.y_v.append(min_razdalja[5])
        
        if min_razdalja[0] == -1:
            self.analiza = False
            print("Zadnja točka na odseku.")
            
        self.c2.translacija_y(self.v.zunanji_premer-min_razdalja[-1])
        self.c2.rotacija(self.v.krozni_korak)
        self.v2.rotacija(3 * self.v.krozni_korak)
        
        self.l_vzmeti = np.sqrt((self.c.tocka0[0] - self.c2.tocka0[2]) ** 2 + (self.c.tocka0[1] - self.c2.tocka0[3]) ** 2)
        
        
        
    def nov_korak_obravnave(self):
        '''Obrne zobnik, približa člen in vpiše točke kontakta'''
        self.v.rotacija(-self.kot_analize)
        self.v2.rotacija(-self.kot_analize)
        
        self.c.translacija_x(1.2 * self.premik_clena)
        
        min_razdalja = None
        for i, (x_c, y_c) in enumerate(zip(self.c.x[3], self.c.y[3])):
            for j, (x_v, y_v) in enumerate(zip(self.v.x[2], self.v.y[2])):
                try:  # Zadnjega clena ne more, ker je index out of range [i+1]
                    if abs(y_v - y_c) < abs(y_c - self.c.y[3][i+1])/2:  # and abs(y_v - y_c) < abs(y_v - self.v.y[[2],[j+1]])/2:
                        razdalja = x_v - x_c
                        if min_razdalja == None or abs(razdalja) < abs(min_razdalja[-1]):
                            min_razdalja = [i, j, x_c, y_c, x_v, y_v, razdalja]
                except:  # Za try mora vedno pridet še except.
                    break

        if abs(min_razdalja[-1]) < 0.25 * self.premik_clena:
            self.c.translacija_x(min_razdalja[-1])

            # Pripenjanje v sezname
            self.x_c.append(min_razdalja[2])
            self.y_c.append(min_razdalja[3] - min_razdalja[-1])
            self.x_v.append(min_razdalja[4])
            self.y_v.append(min_razdalja[5])
            
        else:
            self.analiza = False  # Izklopi while zanko
            
        if np.average((self.c2.tocka0[0], self.c2.tocka0[2])) < 0:
            self.c2.rotacija(-self.kot_analize)
            
        else:
            self.c2.translacija_x(1.2 * self.premik_clena)
        
            min_razdalja = None
            for i, (x_c, y_c) in enumerate(zip(self.c2.x[3], self.c2.y[3])):
                for j, (x_v, y_v) in enumerate(zip(self.v2.x[8], self.v2.y[8])):
                    try:  # Zadnjega clena ne more, ker je index out of range [i+1]
                        if abs(y_v - y_c) < abs(y_c - self.c2.y[3][i+1])/2:  # and abs(y_v - y_c) < abs(y_v - self.v.y[[2],[j+1]])/2:
                            razdalja = x_v - x_c
                            if min_razdalja == None or abs(razdalja) < abs(min_razdalja[-1]):
                                min_razdalja = [i, j, x_c, y_c, x_v, y_v, razdalja]
                    except:  # Za try mora vedno pridet še except.
                        break
                        
            if abs(min_razdalja[-1]) < 0.25 * self.premik_clena:
                self.c2.translacija_x(min_razdalja[-1])
            
                               
    def izris(self):
        '''Izriše člen in verižnik.'''
        
        self.xl = np.linspace(self.c2.tocka0[2], self.c.tocka0[0], 50)
        self.yl = np.linspace(self.c2.tocka0[3], self.c.tocka0[1], 50)
        k = (self.c.tocka0[1] - self.c2.tocka0[3]) / (self.c.tocka0[0] - self.c2.tocka0[2])
        x_t = self.c.tocka0[0]
        y_t = self.c.tocka0[1]
        self.xdod = [x_t]
        self.ydod = [y_t]
        while np.sqrt((x_t - self.c2.tocka0[2]) ** 2 + (y_t - self.c2.tocka0[3]) ** 2) < self.l_vzmeti:
            x_t += 0.01
            y_t += 0.01 * k
            self.xdod.append(x_t)
            self.ydod.append(y_t)
            
        self.c.izris()
        self.c2.izris()
        self.v.izris()
        self.v2.izris()
        plt.plot(self.xl, self.yl)
        plt.plot(self.xdod, self.ydod, 'k')
        plt.show()
    
    def izris_ubirnice(self):
        # Predpostavka kontaktne točke verižnika in člena so enake - zanemarimo napako numerične metode.
        plt.plot(self.x_v, self.y_v, 'g.')
        plt.title("Ubirnica")
        plt.xlabel("mm")
        plt.ylabel("mm")
        plt.show()
        
    def glajenje_ubirnice(self):
        '''Pogladim y vrednosti točk s premičnim povprečjem.'''
        # print("Glajenje ubirnice...")
        self.y_g = premicno_povprecje(self.y_v, 7)
        self.y_v = self.y_g
    
    def relativne_hitrosti(self):
        self.rel_hitrosti = []
        self.koti_kontakta = []
        self.koti_veriznika = []
        self.normalne_hitrosti = []
        kot_veriznika = np.pi / 2
        for x, y in zip(self.x_v, self.y_v):
            r = np.sqrt(x ** 2 + y ** 2)
            v_obodna = omega * r
            theta = np.arctan(y / x)
            if theta < 0:
                theta += np.pi
            phi1 = np.pi - self.c.alpha_r -theta
            phi2 = np.deg2rad(60)
            v_rel = v_obodna * (np.cos(phi1) - np.sin(phi1) / np.tan(phi2))
            v_n = v_obodna * np.sin(phi1)
            self.rel_hitrosti.append(v_rel / 1000)  # pretvorim iz mm/s v m/s
            self.normalne_hitrosti.append(v_n / 1000)  # pretvorim iz mm/s v m/s
            self.koti_kontakta.append(np.rad2deg(theta))
            self.koti_veriznika.append(np.rad2deg(kot_veriznika))
            kot_veriznika -= self.kot_analize
            
        # Izris
        plt.plot(self.koti_kontakta, self.rel_hitrosti, '.')
        plt.title('Drsna hitrost v odvisnosti od kota kontakta')
        plt.xlabel('°')
        plt.ylabel("$\\frac{m}{s}$")
        plt.show()
        
        plt.plot(self.koti_kontakta, self.normalne_hitrosti, '.')
        plt.title('Normalna hitrost v odvisnosti od kota kontakta')
        plt.xlabel('°')
        plt.ylabel("$\\frac{m}{s}$")
        plt.show()
        
        '''
        plt.plot(self.koti_veriznika, self.rel_hitrosti, '.')
        plt.title('Relativne hitrosti v odvisnosti od kota veriznika')
        plt.xlabel('°')
        plt.ylabel("$\\frac{m}{s}$")
        plt.show()
        '''

# %%
Analiza2(podatki[0], 30, np.pi / 300, 1);
# Out:
# Vrsta:  06
# Število zob:  30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-90f53e8fc6bf> in <module>
# ----> 1 Analiza2(podatki[0], 30, np.pi / 300, 1);
#
# <ipython-input-8-a5947e0a278a> in __init__(self, podatki_i, z, kot_analize, prikazi)
#      38         # Ogled in obdelava rezultatov
#      39         # self.izris_ubirnice()
# ---> 40         self.glajenje_ubirnice()
#      41         self.izris_ubirnice()
#      42         self.relativne_hitrosti()
#
# <ipython-input-8-a5947e0a278a> in glajenje_ubirnice(self)
#     167         '''Pogladim y vrednosti točk s premičnim povprečjem.'''
#     168         # print("Glajenje ubirnice...")
# --> 169         self.y_g = premicno_povprecje(self.y_v, 7)
#     170         self.y_v = self.y_g
#     171
#
# NameError: name 'premicno_povprecje' is not defined
